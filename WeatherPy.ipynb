# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from config import weather_api

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 604

# %%
print(len(cities))
# Out:
# 604

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = city_url = f"{url}appid={weather_api}&units=metric&q=" + city

    # requests.get to create jason
    city_response = requests.get(city_url)
    city_json = city_response.json()

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
       # Parse the JSON and retrieve data
        city_weather = city_json
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_json["coord"]["lat"]
        city_lon = city_json["coord"]["lon"]
        city_max_temp = city_json["main"]["temp_max"]
        city_humidity = city_json["main"]["humidity"]
        city_clouds = city_json["clouds"]
        city_wind = city_json["wind"] 
        city_country = city_json["sys"]["country"]
        city_date = city_json["dt"]
    
        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lon": city_lon,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tomatlan
# Processing Record 2 of Set 1 | umm kaddadah
# Processing Record 3 of Set 1 | olonkinbyen
# Processing Record 4 of Set 1 | port-aux-francais
# Processing Record 5 of Set 1 | adamstown
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | tsiombe
# Processing Record 8 of Set 1 | edinburgh of the seven seas
# Processing Record 9 of Set 1 | kayes
# Processing Record 10 of Set 1 | georgetown
# Processing Record 11 of Set 1 | port elizabeth
# Processing Record 12 of Set 1 | shibetsu
# Processing Record 13 of Set 1 | utrik
# Processing Record 14 of Set 1 | ouro sogui
# Processing Record 15 of Set 1 | papatowai
# Processing Record 16 of Set 1 | isafjordur
# Processing Record 17 of Set 1 | lebu
# Processing Record 18 of Set 1 | thompson
# Processing Record 19 of Set 1 | blackmans bay
# Processing Record 20 of Set 1 | iskateley
# ...

# %%
city_json
# Out:
# {'coord': {'lon': -116.7664, 'lat': 32.835},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 22.5,
#   'feels_like': 22.45,
#   'temp_min': 18.18,
#   'temp_max': 26.1,
#   'pressure': 1016,
#   'humidity': 63,
#   'sea_level': 1016,
#   'grnd_level': 946},
#  'visibility': 10000,
#  'wind': {'speed': 0, 'deg': 0},
#  'clouds': {'all': 0},
#  'dt': 1723046519,
#  'sys': {'type': 2,
#   'id': 2008278,
#   'country': 'US',
#   'sunrise': 1723035920,
#   'sunset': 1723084814},
#  'timezone': -25200,
#  'id': 5323401,
#  'name': 'Alpine',
#  'cod': 200}

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.read_csv("Resources/cities.csv")

# Show Record Count
city_data_df.count()
# Out:
# City_ID       577
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       574
# Date          577
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         faya  18.3851   42.4509     22.06        35          21
# 1        1      farsund  58.0948    6.8047     13.30       100           0
# 2        2  new norfolk -42.7826  147.0587     11.72        58          12
# 3        3    jamestown  42.0970  -79.2353      5.77        77         100
# 4        4      lanzhou  36.0564  103.7922     14.53        48          59
#
#    Wind Speed Country        Date
# 0        2.60      SA  1666108228
# 1        7.65      NO  1666108228
# 2        1.34      AU  1666108230
# 3        9.77      US  1666107934
# 4        1.20      CN  1666108230

# %%
# Export the City_Data into a csv
city_data_df.to_csv("Resources/cities.csv", index= False)

# %%
# Read saved data
city_data_df = pd.read_csv("Resources/cities.csv")
# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         faya  18.3851   42.4509     22.06        35          21
# 1        1      farsund  58.0948    6.8047     13.30       100           0
# 2        2  new norfolk -42.7826  147.0587     11.72        58          12
# 3        3    jamestown  42.0970  -79.2353      5.77        77         100
# 4        4      lanzhou  36.0564  103.7922     14.53        48          59
#
#    Wind Speed Country        Date
# 0        2.60      SA  1666108228
# 1        7.65      NO  1666108228
# 2        1.34      AU  1666108230
# 3        9.77      US  1666107934
# 4        1.20      CN  1666108230

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.figure(figsize=(10, 6))
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], color='blue', alpha=0.75)

# Incorporate the other graph properties
plt.title('Max Temperature vs. Latitude')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (°C)')
plt.grid(True)


# Save the figure
plt.savefig("Resources/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.figure(figsize=(10, 6))
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], color='blue', alpha=0.75)

# Incorporate the other graph properties
plt.title("Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(True)
# Save the figure
plt.savefig("Resources/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.figure(figsize=(10, 6))
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], color='blue', alpha=0.75)
# Incorporate the other graph properties
plt.title("Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(True)
# Save the figure
plt.savefig("Resources/Fig3.png")
# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.figure(figsize=(10, 6))
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], color='blue', alpha=0.75)

# Incorporate the other graph properties
plt.title("Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(True)
# Save the figure
plt.savefig("Resources/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
north_hemi_df = city_data_df[city_data_df["Lat"] >=0]

# Display sample data
north_hemi_df.head()
# Out:
#    City_ID       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0       faya  18.3851   42.4509     22.06        35          21
# 1        1    farsund  58.0948    6.8047     13.30       100           0
# 3        3  jamestown  42.0970  -79.2353      5.77        77         100
# 4        4    lanzhou  36.0564  103.7922     14.53        48          59
# 6        6     albany  42.6001  -73.9662     10.36        74          29
#
#    Wind Speed Country        Date
# 0        2.60      SA  1666108228
# 1        7.65      NO  1666108228
# 3        9.77      US  1666107934
# 4        1.20      CN  1666108230
# 6        2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
south_hemi_df = city_data_df[city_data_df["Lat"] <=0]

# Display sample data
south_hemi_df.head()
# Out:
#     City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 2         2   new norfolk -42.7826  147.0587     11.72        58          12
# 5         5       ushuaia -54.8000  -68.3000      8.81        81          75
# 7         7     carnarvon -24.8667  113.6333     20.02        76           0
# 9         9  saint-pierre -21.3393   55.4781     22.82        68           0
# 10       10      colorado -22.8375  -51.9731     20.36        86          96
#
#     Wind Speed Country        Date
# 2         1.34      AU  1666108230
# 5         3.09      AR  1666108231
# 7         7.46      AU  1666108232
# 9         5.14      RE  1666108236
# 10        4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Create a function to preform linear regression 

# function for northern hemisphere
def plot_linear_regression_north(data_df, x_col, y_col, title):
    # Performing the linear regression
    slope, intercept, rvalue, pvalue, stderr = linregress(data_df[x_col], data_df[y_col])

    # Setting variable to print later on the graph
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

    # Creating the scatter plot
    plt.figure(figsize=(10, 6))
    plt.scatter(data_df[x_col], data_df[y_col], color="blue", alpha=0.75)

    # Plotting the linear regression line on the chart
    plt.plot(data_df[x_col], slope * data_df[x_col] + intercept, color="red")
    plt.annotate(line_eq, (10,-10), fontsize=15, color="red")

    # Creating x & y labels plus title
    plt.xlabel(x_col)
    plt.ylabel(y_col)
    plt.title(title)
    print(f"Your r-value is: {rvalue}.")
    plt.show()

# function for southern hemisphere
def plot_linear_regression_south(data_df, x_col, y_col, title):
    # Performing the linear regression
    slope, intercept, rvalue, pvalue, stderr = linregress(data_df[x_col], data_df[y_col])

    # Setting variable to print later on the graph
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))

    # Creating the scatter plot
    plt.figure(figsize=(10, 6))
    plt.scatter(data_df[x_col], data_df[y_col], color="blue", alpha=0.75)

    # Plotting the linear regression line on the chart
    plt.plot(data_df[x_col], slope * data_df[x_col] + intercept, color="red")
    plt.annotate(line_eq, (-20, 10), fontsize=15, color="red")

    # Creating x & y labels plus title
    plt.xlabel(x_col)
    plt.ylabel(y_col)
    plt.title(title)
    print(f"Your r-value is: {rvalue}.")
    plt.show()

# %%
# Linear regression on Northern Hemisphere
plot_linear_regression_north(north_hemi_df, "Lat", "Max Temp", "Latitude vs Max Temp w/ linear regression")
# Out:
# Your r-value is: -0.8462548186825364.

# %%
# Linear regression on Southern Hemisphere
plot_linear_regression_south(south_hemi_df, "Lat", "Max Temp", "Latitude vs Max Temp w/ linear regression")
# Out:
# Your r-value is: 0.6419546065421801.

# %% [markdown]
# **Discussion about the linear relationship:** When observing the two graphs together one could easily conclude that as the latitude of a location increases the overall maximum temperature increases as well. However I do believe that we would need more analysis to be fully sure this trened is accurate. That being said the r(2) values of both charts are very strong so I think it would be a safe assumption to make regarding the data.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression_north(north_hemi_df, "Lat", "Humidity", "Latitude vs Humidity w/ linear regression")
# Out:
# Your r-value is: 0.2385317912939407.

# %%
# Southern Hemisphere
plot_linear_regression_south(south_hemi_df, "Lat", "Humidity", "Latitude vs Humidity w/ linear regression")
# Out:
# Your r-value is: 0.016759316950056818.

# %% [markdown]
# **Discussion about the linear relationship:** I do not believe there is a strong coorlation between latitude and overall humidity for an area. The distribution of points on both charts is very erratic and the overall r(2) value for both of the data sets is very weak.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression_north(north_hemi_df, "Lat", "Cloudiness", "Latitude vs Cloudiness w/ linear regression")
# Out:
# Your r-value is: 0.155004893876971.

# %%
# Southern Hemisphere
plot_linear_regression_south(south_hemi_df, "Lat", "Cloudiness", "Latitude vs Cloudiness w/ linear regression")
# Out:
# Your r-value is: 0.14341322916643243.

# %% [markdown]
# **Discussion about the linear relationship:** Again much like the overall humidity for an area cloudiness doesnt seems to be impacted all that much based on the latitude of a specific location.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression_north(north_hemi_df, "Lat", "Wind Speed", "Latitude vs Wind Speed w/ linear regression")
# Out:
# Your r-value is: 0.1743466729090334.

# %%
# Southern Hemisphere
plot_linear_regression_south(south_hemi_df, "Lat", "Wind Speed", "Latitude vs Wind Speed w/ linear regression")
# Out:
# Your r-value is: -0.24947753546264592.

# %% [markdown]
# **Discussion about the linear relationship:** Again we see a weak coorlation between wind speed and latitude as well.
